# %% [markdown]
# # Exercise
# In exercise folder (same level as this notebook on github) there is hiring.csv. This file contains hiring statics for a firm such as experience of candidate, his written test score and personal interview score. Based on these 3 factors, HR will decide the salary. Given this data, you need to build a machine learning model for HR department that can help them decide salaries for future candidates. Using this predict salaries for following candidates,
#
# ## 2 yr experience, 9 test score, 6 interview score
#
# ## 12 yr experience, 10 test score, 10 interview score

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn import linear_model

# %%
hiring_df = pd.read_csv("hiring.csv", names=["experience", "test", "interview", "salary"], header=0)

# %%
# drop the incomplete data
hiring_df.dropna(inplace=True)
hiring_df.experience=[5,2,7,3,11]

# %%
# fill the incomplete data based on the mean values
# hiring_df.experience=[6,6,5,2,7,3,10,11]
# hiring_df.loc[6, "test"]=8
# hiring_df

# %%
hiring_df
# Out:
#    experience  test  interview  salary
# 2           5   6.0          7   60000
# 3           2  10.0         10   65000
# 4           7   9.0          6   70000
# 5           3   7.0         10   62000
# 7          11   7.0          8   80000

# %%
model=linear_model.LinearRegression()

# %%
model.fit(hiring_df.drop("salary", axis="columns"), hiring_df.salary)
# Out:
# LinearRegression()

# %%
model.predict([[2,9,6]])
# Out:
# C:\Projekty\ml_basics\venv\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([56365.37746374])

# %%
model.predict([[12,10,10]])
# Out:
# C:\Projekty\ml_basics\venv\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([92146.52287096])
